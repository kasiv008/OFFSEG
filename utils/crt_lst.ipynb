# %%
import numpy as np
import os
path=os.getcwd()
path1=path+'/val_image'
path2=path+'/label_rugd'

# %%
ls=os.listdir(path2)

# %%
ls.sort()

# %%
ls
# Out:
# ['creek_00001.png',
#  'creek_00006.png',
#  'creek_00011.png',
#  'creek_00016.png',
#  'creek_00021.png',
#  'creek_00026.png',
#  'creek_00031.png',
#  'creek_00036.png',
#  'creek_00041.png',
#  'creek_00046.png',
#  'creek_00051.png',
#  'creek_00056.png',
#  'creek_00061.png',
#  'creek_00066.png',
#  'creek_00071.png',
#  'creek_00076.png',
#  'creek_00081.png',
#  'creek_00086.png',
#  'creek_00091.png',
#  'creek_00096.png',
#  'creek_00101.png',
#  'creek_00106.png',
#  'creek_00111.png',
#  'creek_00116.png',
#  'creek_00121.png',
#  'creek_00126.png',
#  'creek_00131.png',
#  'creek_00136.png',
#  'creek_00141.png',
#  'creek_00146.png',
#  'creek_00151.png',
#  'creek_00156.png',
#  'creek_00161.png',
#  'creek_00166.png',
#  'creek_00171.png',
#  'creek_00176.png',
#  'creek_00181.png',
#  'creek_00186.png',
#  'creek_00191.png',
#  'creek_00196.png',
#  'creek_00201.png',
#  'creek_00206.png',
#  'creek_00211.png',
#  'creek_00216.png',
#  'creek_00221.png',
# ...

# %%
f=[]
for i in ls:
    sz=len(i)
    k= i[:sz - 3]
    f.append(k)

# %%
f
# Out:
# ['frame000000-1581623790_349.',
#  'frame000000-1581624075_250.',
#  'frame000000-1581624652_750.',
#  'frame000000-1581791678_408.',
#  'frame000000-1581797150_409.',
#  'frame000002-1581623790_549.',
#  'frame000002-1581624075_450.',
#  'frame000002-1581624652_949.',
#  'frame000002-1581791678_608.',
#  'frame000002-1581797150_609.',
#  'frame000004-1581623790_749.',
#  'frame000004-1581624075_649.',
#  'frame000004-1581624653_150.',
#  'frame000004-1581791678_808.',
#  'frame000004-1581797150_809.',
#  'frame000006-1581623790_949.',
#  'frame000006-1581624075_849.',
#  'frame000006-1581624653_349.',
#  'frame000006-1581791679_008.',
#  'frame000006-1581797151_009.',
#  'frame000008-1581623791_149.',
#  'frame000008-1581624076_049.',
#  'frame000008-1581624653_549.',
#  'frame000008-1581791679_208.',
#  'frame000008-1581797151_209.',
#  'frame000010-1581623791_349.',
#  'frame000010-1581624076_249.',
#  'frame000010-1581624653_749.',
#  'frame000010-1581791679_408.',
# ...

# %%
with open("train.txt","w") as m:
    for student in ls:
        u=path+'/label_rugd/'+student
        j=path+'/image_rugd/'+student
        #j=path+'/test/'+student
        m.write("{0} {1}\n".format(j,u))
